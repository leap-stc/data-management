# %% [markdown]
# # Example: Uploading an xarray dataset to zarr
#
# This notebook explains the basic steps needed to upload a small to moderatly sized dataset manually to the [persistent cloud bucket](https://infrastructure.2i2c.org/en/latest/topic/features.html?highlight=persistent%20bucket#persistent-buckets-on-object-storage) for LEAP.
#
# You will learn the following things:
#
# - How to upload an xarray Dataset into a cloud bucket using the zarr format
# - How to share the url and enable other LEAP users to access the data from within the Jupyterhub
# - How to delete data from the cloud bucket
#
# <div class="admonition note" name="html-admonition" style="background: pink; padding: 5px">
# <p class="title">Warning:🚨 Before you start!
#
# Storing large amounts of data in the persistent cloud bucket can <b>dramatically increase</b> cost for the whole project.
# Please be mindful of this community resource by following these rules:
# <ul>
#     <li>Make sure that your data is backed up in a second location, the cloud storage is meant for easy collaboration and analysis not as a permanent archive</li>
#     <li>Discuss adding data over a few GBs with the Data and Computation Manager Julius Busecke (Slack:<it> @Julius Busecke</it>, 📧: julius@ldeo.columbia.edu)</li>
#     <li>Delete data immeatly when it is not needed anymore</li>
# </ul>
# </p>
# </div>

# %%
import xarray as xr
import gcsfs
import os
import zarr
import dask

# %%
sp_path = "/ocean/projects/atm200007p/jlin96/longSPrun_o3/"

# %%
spData = xr.open_mfdataset(
    [
        sp_path + "AndKua_aqua_Base_training.cam2.h1.0001-12-09-00000.nc",
        sp_path + "AndKua_aqua_Base_training.cam2.h1.0001-12-10-00000.nc",
        sp_path + "AndKua_aqua_Base_training.cam2.h1.0001-12-11-00000.nc",
    ],
    decode_times=False,
)

# %% [markdown]
# First we need to identify the persistent cloud bucket and user folder to which we will upload our data. This information is stored in the environmental variable `"PERSISTENT_BUCKET"`
#
# > Note: You can use the same workflow to store temporary data by using the `"SCRATCH_BUCKET" (this data is deleted after 7 days).

# %%
os.environ['PERSISTENT_BUCKET']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 os.environ['PERSISTENT_BUCKET']
#
# File ~/.conda/envs/leapexample/lib/python3.10/os.py:680, in _Environ.__getitem__(self, key)
#     677     value = self._data[self.encodekey(key)]
#     678 except KeyError:
#     679     # raise KeyError with the original key value
# --> 680     raise KeyError(key) from None
#     681 return self.decodevalue(value)
#
# KeyError: 'PERSISTENT_BUCKET'

# %% [markdown]
# 👆 This should show a path including your github username

# %% [markdown]
# For the sake of this example I am going to create a very simple dataset in the notebook, but you can substitute any other `xarray.Dataset` (e.g. one loaded from netcdf via `xr.open_dataset()`

# %%
ds = xr.DataArray([1, 4, 6]).to_dataset(name='data')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (dim_0: 3)
# Dimensions without coordinates: dim_0
# Data variables:
#     data     (dim_0) int64 1 4 6

# %% [markdown]
# In order to save a zarr store similarly to how you would on a traditional filesystem we need to set up a cloud filesystem and a mapper.

# %%
fs = gcsfs.GCSFileSystem()
mapper = fs.get_mapper("gs://leap-persistent/jbusecke/testing/demo_write.zarr")

# %% [markdown]
# This mapper can then be used similarly to a filepath to save an xarray Dataset as a zarr store using `xr.Dataset.to_zarr()`

# %%
ds.to_zarr(mapper)
# Out:
# _request non-retriable exception: Anonymous caller does not have storage.objects.get access to the Google Cloud Storage object. Permission 'storage.objects.get' denied on resource (or it may not exist)., 401
# Traceback (most recent call last):
#   File "/jet/home/jlin96/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py", line 114, in retry_request
#     return await func(*args, **kwargs)
#   File "/jet/home/jlin96/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py", line 411, in _request
#     validate_response(status, contents, path, args)
#   File "/jet/home/jlin96/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py", line 101, in validate_response
#     raise HttpError(error)
# gcsfs.retry.HttpError: Anonymous caller does not have storage.objects.get access to the Google Cloud Storage object. Permission 'storage.objects.get' denied on resource (or it may not exist)., 401
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 ds.to_zarr(mapper)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/xarray/core/dataset.py:2098, in Dataset.to_zarr(self, store, chunk_store, mode, synchronizer, group, encoding, compute, consolidated, append_dim, region, safe_chunks, storage_options, zarr_version)
#    1981 """Write dataset contents to a zarr group.
#    1982
#    1983 Zarr chunks are determined in the following way:
#    (...)
#    2094     The I/O user guide, with more details and examples.
#    2095 """
#    2096 from xarray.backends.api import to_zarr
# -> 2098 return to_zarr(  # type: ignore
#    2099     self,
#    2100     store=store,
#    2101     chunk_store=chunk_store,
#    2102     storage_options=storage_options,
#    2103     mode=mode,
#    2104     synchronizer=synchronizer,
#    2105     group=group,
#    2106     encoding=encoding,
#    2107     compute=compute,
#    2108     consolidated=consolidated,
#    2109     append_dim=append_dim,
#    2110     region=region,
#    2111     safe_chunks=safe_chunks,
#    2112     zarr_version=zarr_version,
#    2113 )
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/xarray/backends/api.py:1614, in to_zarr(dataset, store, chunk_store, mode, synchronizer, group, encoding, compute, consolidated, append_dim, region, safe_chunks, storage_options, zarr_version)
#    1612     already_consolidated = False
#    1613     consolidate_on_close = consolidated or consolidated is None
# -> 1614 zstore = backends.ZarrStore.open_group(
#    1615     store=mapper,
#    1616     mode=mode,
#    1617     synchronizer=synchronizer,
#    1618     group=group,
#    1619     consolidated=already_consolidated,
#    1620     consolidate_on_close=consolidate_on_close,
#    1621     chunk_store=chunk_mapper,
#    1622     append_dim=append_dim,
#    1623     write_region=region,
#    1624     safe_chunks=safe_chunks,
#    1625     stacklevel=4,  # for Dataset.to_zarr()
#    1626     zarr_version=zarr_version,
#    1627 )
#    1629 if mode in ["a", "r+"]:
#    1630     _validate_datatypes_for_zarr_append(zstore, dataset)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/xarray/backends/zarr.py:430, in ZarrStore.open_group(cls, store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, append_dim, write_region, safe_chunks, stacklevel, zarr_version)
#     428     zarr_group = zarr.open_consolidated(store, **open_kwargs)
#     429 else:
# --> 430     zarr_group = zarr.open_group(store, **open_kwargs)
#     431 return cls(
#     432     zarr_group,
#     433     mode,
#    (...)
#     437     safe_chunks,
#     438 )
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/zarr/hierarchy.py:1455, in open_group(store, mode, cache_attrs, synchronizer, path, chunk_store, storage_options, zarr_version, meta_array)
#    1452         init_group(store, path=path, chunk_store=chunk_store)
#    1454 elif mode in ['w-', 'x']:
# -> 1455     if contains_array(store, path=path):
#    1456         raise ContainsArrayError(path)
#    1457     elif contains_group(store, path=path):
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/zarr/storage.py:107, in contains_array(store, path)
#     105 prefix = _path_to_prefix(path)
#     106 key = _prefix_to_array_key(store, prefix)
# --> 107 return key in store
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/zarr/storage.py:1430, in FSStore.__contains__(self, key)
#    1428 def __contains__(self, key):
#    1429     key = self._normalize_key(key)
# -> 1430     return key in self.map
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/mapping.py:181, in FSMap.__contains__(self, key)
#     179 """Does key exist in mapping?"""
#     180 path = self._key_to_str(key)
# --> 181 return self.fs.exists(path) and self.fs.isfile(path)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/asyn.py:114, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     111 @functools.wraps(func)
#     112 def wrapper(*args, **kwargs):
#     113     self = obj or args[0]
# --> 114     return sync(self.loop, func, *args, **kwargs)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/asyn.py:99, in sync(loop, func, timeout, *args, **kwargs)
#      97     raise FSTimeoutError from return_result
#      98 elif isinstance(return_result, BaseException):
# ---> 99     raise return_result
#     100 else:
#     101     return return_result
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/asyn.py:54, in _runner(event, coro, result, timeout)
#      52     coro = asyncio.wait_for(coro, timeout=timeout)
#      53 try:
# ---> 54     result[0] = await coro
#      55 except Exception as ex:
#      56     result[0] = ex
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/asyn.py:568, in AsyncFileSystem._exists(self, path)
#     566 async def _exists(self, path):
#     567     try:
# --> 568         await self._info(path)
#     569         return True
#     570     except FileNotFoundError:
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py:791, in GCSFileSystem._info(self, path, generation, **kwargs)
#     789 # Check exact file path
#     790 try:
# --> 791     exact = await self._get_object(path)
#     792     # this condition finds a "placeholder" - still need to check if it's a directory
#     793     if exact["size"] or not exact["name"].endswith("/"):
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py:491, in GCSFileSystem._get_object(self, path)
#     488 # Work around various permission settings. Prefer an object get (storage.objects.get), but
#     489 # fall back to a bucket list + filter to object name (storage.objects.list).
#     490 try:
# --> 491     res = await self._call(
#     492         "GET", "b/{}/o/{}", bucket, key, json_out=True, generation=generation
#     493     )
#     494 except OSError as e:
#     495     if not str(e).startswith("Forbidden"):
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py:418, in GCSFileSystem._call(self, method, path, json_out, info_out, *args, **kwargs)
#     414 async def _call(
#     415     self, method, path, *args, json_out=False, info_out=False, **kwargs
#     416 ):
#     417     logger.debug(f"{method.upper()}: {path}, {args}, {kwargs.get('headers')}")
# --> 418     status, headers, info, contents = await self._request(
#     419         method, path, *args, **kwargs
#     420     )
#     421     if json_out:
#     422         return json.loads(contents)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/decorator.py:221, in decorate.<locals>.fun(*args, **kw)
#     219 if not kwsyntax:
#     220     args, kw = fix(args, kw, sig)
# --> 221 return await caller(func, *(extras + args), **kw)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py:149, in retry_request(func, retries, *args, **kwargs)
#     147     continue
#     148 logger.exception(f"{func.__name__} non-retriable exception: {e}")
# --> 149 raise e
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py:114, in retry_request(func, retries, *args, **kwargs)
#     112     if retry > 0:
#     113         await asyncio.sleep(min(random.random() + 2 ** (retry - 1), 32))
# --> 114     return await func(*args, **kwargs)
#     115 except (
#     116     HttpError,
#     117     requests.exceptions.RequestException,
#    (...)
#     120     aiohttp.client_exceptions.ClientError,
#     121 ) as e:
#     122     if (
#     123         isinstance(e, HttpError)
#     124         and e.code == 400
#     125         and "requester pays" in e.message
#     126     ):
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py:411, in GCSFileSystem._request(self, method, path, headers, json, data, *args, **kwargs)
#     408 info = r.request_info  # for debug only
#     409 contents = await r.read()
# --> 411 validate_response(status, contents, path, args)
#     412 return status, headers, info, contents
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py:101, in validate_response(status, content, path, args)
#      99     raise ValueError(f"Bad Request: {path}\n{msg}")
#     100 elif error:
# --> 101     raise HttpError(error)
#     102 elif status:
#     103     raise HttpError({"code": status, "message": msg})  # text-like
#
# HttpError: Anonymous caller does not have storage.objects.get access to the Google Cloud Storage object. Permission 'storage.objects.get' denied on resource (or it may not exist)., 401

# %% [markdown]
# ## Checking that files were written
#
# You can use the convinence function `.ls`, similarly to calling the UNIX function `ls` in a terminal, to list contents of your bucket (or subfolders)

# %%
fs.ls("gs://leap-persistent/jbusecke/testing/")
# Out:
# _request non-retriable exception: Anonymous caller does not have storage.objects.list access to the Google Cloud Storage bucket. Permission 'storage.objects.list' denied on resource (or it may not exist)., 401
# Traceback (most recent call last):
#   File "/jet/home/jlin96/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py", line 114, in retry_request
#     return await func(*args, **kwargs)
#   File "/jet/home/jlin96/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py", line 411, in _request
#     validate_response(status, contents, path, args)
#   File "/jet/home/jlin96/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py", line 101, in validate_response
#     raise HttpError(error)
# gcsfs.retry.HttpError: Anonymous caller does not have storage.objects.list access to the Google Cloud Storage bucket. Permission 'storage.objects.list' denied on resource (or it may not exist)., 401
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 fs.ls("gs://leap-persistent/jbusecke/testing/")
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/asyn.py:114, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     111 @functools.wraps(func)
#     112 def wrapper(*args, **kwargs):
#     113     self = obj or args[0]
# --> 114     return sync(self.loop, func, *args, **kwargs)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/asyn.py:99, in sync(loop, func, timeout, *args, **kwargs)
#      97     raise FSTimeoutError from return_result
#      98 elif isinstance(return_result, BaseException):
# ---> 99     raise return_result
#     100 else:
#     101     return return_result
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/asyn.py:54, in _runner(event, coro, result, timeout)
#      52     coro = asyncio.wait_for(coro, timeout=timeout)
#      53 try:
# ---> 54     result[0] = await coro
#      55 except Exception as ex:
#      56     result[0] = ex
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py:835, in GCSFileSystem._ls(self, path, detail, prefix, versions, **kwargs)
#     833 else:
#     834     out = []
# --> 835     for entry in await self._list_objects(
#     836         path, prefix=prefix, versions=versions
#     837     ):
#     838         if versions:
#     839             out.append(
#     840                 {
#     841                     **entry,
#     842                     "name": f"{entry['name']}#{entry['generation']}",
#     843                 }
#     844             )
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py:533, in GCSFileSystem._list_objects(self, path, prefix, versions)
#     530     if key:
#     531         raise
# --> 533 items, prefixes = await self._do_list_objects(
#     534     path, prefix=prefix, versions=versions
#     535 )
#     537 pseudodirs = [
#     538     {
#     539         "bucket": bucket,
#    (...)
#     545     for prefix in prefixes
#     546 ]
#     547 if not (items + pseudodirs):
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py:568, in GCSFileSystem._do_list_objects(self, path, max_results, delimiter, prefix, versions)
#     566 prefixes = []
#     567 items = []
# --> 568 page = await self._call(
#     569     "GET",
#     570     "b/{}/o",
#     571     bucket,
#     572     delimiter=delimiter,
#     573     prefix=prefix,
#     574     maxResults=max_results,
#     575     json_out=True,
#     576     versions="true" if versions or generation else None,
#     577 )
#     579 prefixes.extend(page.get("prefixes", []))
#     580 items.extend(page.get("items", []))
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py:418, in GCSFileSystem._call(self, method, path, json_out, info_out, *args, **kwargs)
#     414 async def _call(
#     415     self, method, path, *args, json_out=False, info_out=False, **kwargs
#     416 ):
#     417     logger.debug(f"{method.upper()}: {path}, {args}, {kwargs.get('headers')}")
# --> 418     status, headers, info, contents = await self._request(
#     419         method, path, *args, **kwargs
#     420     )
#     421     if json_out:
#     422         return json.loads(contents)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/decorator.py:221, in decorate.<locals>.fun(*args, **kw)
#     219 if not kwsyntax:
#     220     args, kw = fix(args, kw, sig)
# --> 221 return await caller(func, *(extras + args), **kw)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py:149, in retry_request(func, retries, *args, **kwargs)
#     147     continue
#     148 logger.exception(f"{func.__name__} non-retriable exception: {e}")
# --> 149 raise e
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py:114, in retry_request(func, retries, *args, **kwargs)
#     112     if retry > 0:
#     113         await asyncio.sleep(min(random.random() + 2 ** (retry - 1), 32))
# --> 114     return await func(*args, **kwargs)
#     115 except (
#     116     HttpError,
#     117     requests.exceptions.RequestException,
#    (...)
#     120     aiohttp.client_exceptions.ClientError,
#     121 ) as e:
#     122     if (
#     123         isinstance(e, HttpError)
#     124         and e.code == 400
#     125         and "requester pays" in e.message
#     126     ):
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py:411, in GCSFileSystem._request(self, method, path, headers, json, data, *args, **kwargs)
#     408 info = r.request_info  # for debug only
#     409 contents = await r.read()
# --> 411 validate_response(status, contents, path, args)
#     412 return status, headers, info, contents
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py:101, in validate_response(status, content, path, args)
#      99     raise ValueError(f"Bad Request: {path}\n{msg}")
#     100 elif error:
# --> 101     raise HttpError(error)
#     102 elif status:
#     103     raise HttpError({"code": status, "message": msg})  # text-like
#
# HttpError: Anonymous caller does not have storage.objects.list access to the Google Cloud Storage bucket. Permission 'storage.objects.list' denied on resource (or it may not exist)., 401

# %% [markdown]
# 🎉 You just wrote your first data to the cloud!

# %% [markdown]
# ## How to access the data from the cloud
#
# This data is now available to read for everyone who is a leap member!
# If you want to enable a collaborator to easily load the data into an xarray Dataset you can given them the following snippet (or add this to a notebook in a github repository):

# %%
import xarray as xr
import gcsfs

fs = gcsfs.GCSFileSystem()
mapper = fs.get_mapper("leap-persistent/jbusecke/testing/demo_write.zarr")
ds_new = xr.open_dataset(mapper, engine='zarr')
ds_new
# Out:
# _request non-retriable exception: Anonymous caller does not have storage.objects.get access to the Google Cloud Storage object. Permission &#39;storage.objects.get&#39; denied on resource (or it may not exist)., 401
# Traceback (most recent call last):
#   File "/jet/home/jlin96/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py", line 114, in retry_request
#     return await func(*args, **kwargs)
#   File "/jet/home/jlin96/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py", line 411, in _request
#     validate_response(status, contents, path, args)
#   File "/jet/home/jlin96/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py", line 103, in validate_response
#     raise HttpError({"code": status, "message": msg})  # text-like
# gcsfs.retry.HttpError: Anonymous caller does not have storage.objects.get access to the Google Cloud Storage object. Permission &#39;storage.objects.get&#39; denied on resource (or it may not exist)., 401
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       3 fs = gcsfs.GCSFileSystem()
#       4 mapper = fs.get_mapper("leap-persistent/jbusecke/testing/demo_write.zarr")
# ----> 5 ds_new = xr.open_dataset(mapper, engine='zarr')
#       6 ds_new
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/xarray/backends/api.py:526, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, backend_kwargs, **kwargs)
#     514 decoders = _resolve_decoders_kwargs(
#     515     decode_cf,
#     516     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     522     decode_coords=decode_coords,
#     523 )
#     525 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 526 backend_ds = backend.open_dataset(
#     527     filename_or_obj,
#     528     drop_variables=drop_variables,
#     529     **decoders,
#     530     **kwargs,
#     531 )
#     532 ds = _dataset_from_backend_dataset(
#     533     backend_ds,
#     534     filename_or_obj,
#    (...)
#     542     **kwargs,
#     543 )
#     544 return ds
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/xarray/backends/zarr.py:891, in ZarrBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, stacklevel, zarr_version)
#     871 def open_dataset(
#     872     self,
#     873     filename_or_obj,
#    (...)
#     888     zarr_version=None,
#     889 ):
#     890     filename_or_obj = _normalize_path(filename_or_obj)
# --> 891     store = ZarrStore.open_group(
#     892         filename_or_obj,
#     893         group=group,
#     894         mode=mode,
#     895         synchronizer=synchronizer,
#     896         consolidated=consolidated,
#     897         consolidate_on_close=False,
#     898         chunk_store=chunk_store,
#     899         storage_options=storage_options,
#     900         stacklevel=stacklevel + 1,
#     901         zarr_version=zarr_version,
#     902     )
#     904     store_entrypoint = StoreBackendEntrypoint()
#     905     with close_on_error(store):
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/xarray/backends/zarr.py:405, in ZarrStore.open_group(cls, store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, append_dim, write_region, safe_chunks, stacklevel, zarr_version)
#     403 if consolidated is None:
#     404     try:
# --> 405         zarr_group = zarr.open_consolidated(store, **open_kwargs)
#     406     except KeyError:
#     407         try:
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/zarr/convenience.py:1299, in open_consolidated(store, metadata_key, mode, **kwargs)
#    1296         metadata_key = 'meta/root/consolidated/' + metadata_key
#    1298 # setup metadata store
# -> 1299 meta_store = ConsolidatedStoreClass(store, metadata_key=metadata_key)
#    1301 # pass through
#    1302 chunk_store = kwargs.pop('chunk_store', None) or store
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/zarr/storage.py:2873, in ConsolidatedMetadataStore.__init__(self, store, metadata_key)
#    2870 self.store = Store._ensure_store(store)
#    2872 # retrieve consolidated metadata
# -> 2873 meta = json_loads(self.store[metadata_key])
#    2875 # check format of consolidated metadata
#    2876 consolidated_format = meta.get('zarr_consolidated_format', None)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/zarr/storage.py:1386, in FSStore.__getitem__(self, key)
#    1384 key = self._normalize_key(key)
#    1385 try:
# -> 1386     return self.map[key]
#    1387 except self.exceptions as e:
#    1388     raise KeyError(key) from e
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/mapping.py:143, in FSMap.__getitem__(self, key, default)
#     141 k = self._key_to_str(key)
#     142 try:
# --> 143     result = self.fs.cat(k)
#     144 except self.missing_exceptions:
#     145     if default is not None:
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/asyn.py:114, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     111 @functools.wraps(func)
#     112 def wrapper(*args, **kwargs):
#     113     self = obj or args[0]
# --> 114     return sync(self.loop, func, *args, **kwargs)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/asyn.py:99, in sync(loop, func, timeout, *args, **kwargs)
#      97     raise FSTimeoutError from return_result
#      98 elif isinstance(return_result, BaseException):
# ---> 99     raise return_result
#     100 else:
#     101     return return_result
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/asyn.py:54, in _runner(event, coro, result, timeout)
#      52     coro = asyncio.wait_for(coro, timeout=timeout)
#      53 try:
# ---> 54     result[0] = await coro
#      55 except Exception as ex:
#      56     result[0] = ex
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/asyn.py:409, in AsyncFileSystem._cat(self, path, recursive, on_error, batch_size, **kwargs)
#     407     ex = next(filter(is_exception, out), False)
#     408     if ex:
# --> 409         raise ex
#     410 if (
#     411     len(paths) > 1
#     412     or isinstance(path, list)
#     413     or paths[0] != self._strip_protocol(path)
#     414 ):
#     415     return {
#     416         k: v
#     417         for k, v in zip(paths, out)
#     418         if on_error != "omit" or not is_exception(v)
#     419     }
#
# File ~/.conda/envs/leapexample/lib/python3.10/asyncio/tasks.py:408, in wait_for(fut, timeout)
#     405 loop = events.get_running_loop()
#     407 if timeout is None:
# --> 408     return await fut
#     410 if timeout <= 0:
#     411     fut = ensure_future(fut, loop=loop)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py:872, in GCSFileSystem._cat_file(self, path, start, end, **kwargs)
#     870 else:
#     871     head = {}
# --> 872 headers, out = await self._call("GET", u2, headers=head)
#     873 return out
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py:418, in GCSFileSystem._call(self, method, path, json_out, info_out, *args, **kwargs)
#     414 async def _call(
#     415     self, method, path, *args, json_out=False, info_out=False, **kwargs
#     416 ):
#     417     logger.debug(f"{method.upper()}: {path}, {args}, {kwargs.get('headers')}")
# --> 418     status, headers, info, contents = await self._request(
#     419         method, path, *args, **kwargs
#     420     )
#     421     if json_out:
#     422         return json.loads(contents)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/decorator.py:221, in decorate.<locals>.fun(*args, **kw)
#     219 if not kwsyntax:
#     220     args, kw = fix(args, kw, sig)
# --> 221 return await caller(func, *(extras + args), **kw)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py:149, in retry_request(func, retries, *args, **kwargs)
#     147     continue
#     148 logger.exception(f"{func.__name__} non-retriable exception: {e}")
# --> 149 raise e
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py:114, in retry_request(func, retries, *args, **kwargs)
#     112     if retry > 0:
#     113         await asyncio.sleep(min(random.random() + 2 ** (retry - 1), 32))
# --> 114     return await func(*args, **kwargs)
#     115 except (
#     116     HttpError,
#     117     requests.exceptions.RequestException,
#    (...)
#     120     aiohttp.client_exceptions.ClientError,
#     121 ) as e:
#     122     if (
#     123         isinstance(e, HttpError)
#     124         and e.code == 400
#     125         and "requester pays" in e.message
#     126     ):
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py:411, in GCSFileSystem._request(self, method, path, headers, json, data, *args, **kwargs)
#     408 info = r.request_info  # for debug only
#     409 contents = await r.read()
# --> 411 validate_response(status, contents, path, args)
#     412 return status, headers, info, contents
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py:103, in validate_response(status, content, path, args)
#     101     raise HttpError(error)
#     102 elif status:
# --> 103     raise HttpError({"code": status, "message": msg})  # text-like
#     104 else:
#     105     raise RuntimeError(msg)
#
# HttpError: Anonymous caller does not have storage.objects.get access to the Google Cloud Storage object. Permission &#39;storage.objects.get&#39; denied on resource (or it may not exist)., 401

# %% [markdown]
# Make sure to hardcode the path 👆 so that another user does not accidentally uses the path defined in `os.environ["PERSISTENT BUCKET"]`

# %% [markdown]
# ## How to delete existing cloud stores
#
# As mentioned above, you should delete data as soon as you are not working on it anymore. Again you can use the convinience function `.rm` on the cloud filesystem object which works similar to the [rm](https://en.wikipedia.org/wiki/Rm_(Unix)) Unix command in the shell.
#
# > As with the `rm -r` command in linux, be careful that you know exactly what you are deleting!

# %%
fs.rm('leap-persistent/jbusecke/testing/demo_write.zarr', recursive=True)
# Out:
# _request non-retriable exception: Anonymous caller does not have storage.objects.list access to the Google Cloud Storage bucket. Permission 'storage.objects.list' denied on resource (or it may not exist)., 401
# Traceback (most recent call last):
#   File "/jet/home/jlin96/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py", line 114, in retry_request
#     return await func(*args, **kwargs)
#   File "/jet/home/jlin96/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py", line 411, in _request
#     validate_response(status, contents, path, args)
#   File "/jet/home/jlin96/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py", line 101, in validate_response
#     raise HttpError(error)
# gcsfs.retry.HttpError: Anonymous caller does not have storage.objects.list access to the Google Cloud Storage bucket. Permission 'storage.objects.list' denied on resource (or it may not exist)., 401
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 fs.rm('leap-persistent/jbusecke/testing/demo_write.zarr', recursive=True)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/asyn.py:114, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     111 @functools.wraps(func)
#     112 def wrapper(*args, **kwargs):
#     113     self = obj or args[0]
# --> 114     return sync(self.loop, func, *args, **kwargs)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/asyn.py:99, in sync(loop, func, timeout, *args, **kwargs)
#      97     raise FSTimeoutError from return_result
#      98 elif isinstance(return_result, BaseException):
# ---> 99     raise return_result
#     100 else:
#     101     return return_result
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/asyn.py:54, in _runner(event, coro, result, timeout)
#      52     coro = asyncio.wait_for(coro, timeout=timeout)
#      53 try:
# ---> 54     result[0] = await coro
#      55 except Exception as ex:
#      56     result[0] = ex
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py:1062, in GCSFileSystem._rm(self, path, recursive, maxdepth, batchsize)
#    1061 async def _rm(self, path, recursive=False, maxdepth=None, batchsize=20):
# -> 1062     paths = await self._expand_path(path, recursive=recursive, maxdepth=maxdepth)
#    1063     files = [p for p in paths if self.split_path(p)[1]]
#    1064     dirs = [p for p in paths if not self.split_path(p)[1]]
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/asyn.py:737, in AsyncFileSystem._expand_path(self, path, recursive, maxdepth)
#     734     raise ValueError("maxdepth must be at least 1")
#     736 if isinstance(path, str):
# --> 737     out = await self._expand_path([path], recursive, maxdepth)
#     738 else:
#     739     out = set()
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/fsspec/asyn.py:753, in AsyncFileSystem._expand_path(self, path, recursive, maxdepth)
#     751     continue
#     752 elif recursive:
# --> 753     rec = set(await self._find(p, maxdepth=maxdepth, withdirs=True))
#     754     out |= rec
#     755 if p not in out and (recursive is False or (await self._exists(p))):
#     756     # should only check once, for the root
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py:1203, in GCSFileSystem._find(self, path, withdirs, detail, prefix, versions, **kwargs)
#    1200 else:
#    1201     _prefix = key
# -> 1203 objects, _ = await self._do_list_objects(
#    1204     bucket, delimiter="", prefix=_prefix, versions=versions
#    1205 )
#    1207 dirs = {}
#    1208 cache_entries = {}
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py:568, in GCSFileSystem._do_list_objects(self, path, max_results, delimiter, prefix, versions)
#     566 prefixes = []
#     567 items = []
# --> 568 page = await self._call(
#     569     "GET",
#     570     "b/{}/o",
#     571     bucket,
#     572     delimiter=delimiter,
#     573     prefix=prefix,
#     574     maxResults=max_results,
#     575     json_out=True,
#     576     versions="true" if versions or generation else None,
#     577 )
#     579 prefixes.extend(page.get("prefixes", []))
#     580 items.extend(page.get("items", []))
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py:418, in GCSFileSystem._call(self, method, path, json_out, info_out, *args, **kwargs)
#     414 async def _call(
#     415     self, method, path, *args, json_out=False, info_out=False, **kwargs
#     416 ):
#     417     logger.debug(f"{method.upper()}: {path}, {args}, {kwargs.get('headers')}")
# --> 418     status, headers, info, contents = await self._request(
#     419         method, path, *args, **kwargs
#     420     )
#     421     if json_out:
#     422         return json.loads(contents)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/decorator.py:221, in decorate.<locals>.fun(*args, **kw)
#     219 if not kwsyntax:
#     220     args, kw = fix(args, kw, sig)
# --> 221 return await caller(func, *(extras + args), **kw)
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py:149, in retry_request(func, retries, *args, **kwargs)
#     147     continue
#     148 logger.exception(f"{func.__name__} non-retriable exception: {e}")
# --> 149 raise e
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py:114, in retry_request(func, retries, *args, **kwargs)
#     112     if retry > 0:
#     113         await asyncio.sleep(min(random.random() + 2 ** (retry - 1), 32))
# --> 114     return await func(*args, **kwargs)
#     115 except (
#     116     HttpError,
#     117     requests.exceptions.RequestException,
#    (...)
#     120     aiohttp.client_exceptions.ClientError,
#     121 ) as e:
#     122     if (
#     123         isinstance(e, HttpError)
#     124         and e.code == 400
#     125         and "requester pays" in e.message
#     126     ):
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/core.py:411, in GCSFileSystem._request(self, method, path, headers, json, data, *args, **kwargs)
#     408 info = r.request_info  # for debug only
#     409 contents = await r.read()
# --> 411 validate_response(status, contents, path, args)
#     412 return status, headers, info, contents
#
# File ~/.conda/envs/leapexample/lib/python3.10/site-packages/gcsfs/retry.py:101, in validate_response(status, content, path, args)
#      99     raise ValueError(f"Bad Request: {path}\n{msg}")
#     100 elif error:
# --> 101     raise HttpError(error)
#     102 elif status:
#     103     raise HttpError({"code": status, "message": msg})  # text-like
#
# HttpError: Anonymous caller does not have storage.objects.list access to the Google Cloud Storage bucket. Permission 'storage.objects.list' denied on resource (or it may not exist)., 401

# %% [markdown]
# Ok lets quickly check that the store is indeed deleted

# %%
fs.ls('leap-persistent/jbusecke/testing')

# %% [markdown]
# And indeed `demo_write.zarr` is gone.

# %%
ds_zarr = xr.Dataset.to_zarr(ds)
z = zarr.zeros((10000, 10000), chunks=(1000, 1000), dtype='i4')
# ?xr.Dataset.to_zarr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 ds_zarr = xr.Dataset.to_zarr(ds)
# ----> 2 z = zarr.zeros((10000, 10000), chunks=(1000, 1000), dtype='i4')
#       3 get_ipython().run_line_magic('pinfo', 'xr.Dataset.to_zarr')
#
# NameError: name 'zarr' is not defined

# %%
ds_zarr = xr.Dataset.to_zarr(ds)

# %%
import zarr

# %%
z = zarr.zeros((10000, 10000), chunks=(1000, 1000), dtype='i4')

# %%
z
# Out:
# <zarr.core.Array (10000, 10000) int32>
